# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ayushdevo/10x.ai/blob/main/work/notebooks/capstone.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %%
Question

Define the 30-day search-visibility prediction problem.
State the decision it supports: which content opportunities to prioritize.

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %%
Identify the public dataset/release and relevant tables.
State the date window.
Document exclusions such as incomplete records or fields unavailable before the prediction point.
Explicitly avoid client names, private queries, or URLs.

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %%
Define the prediction unit.
Define the label: future search-visibility growth over the next 30 days.
Features should only use information available at prediction time.
Establish a simple baseline first.
Use a time-aware validation strategy.
Include leakage checks.

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %%
Same validation split for both.
Show baseline metric(s).
Show model metric(s).
Report the actual measured improvement rather than claiming the model is “excellent.”

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %%
Observational data ≠ causal evidence.
Predictions indicate opportunities, not guaranteed rankings/traffic.
Performance depends on the available historical data and feature coverage.
A 30-day horizon limits what can be inferred about long-term content performance.

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %%
Convert model output into an actionable ranking.
Example structure:
Highest predicted growth opportunities
Opportunities with sufficient historical evidence
Lower-confidence opportunities requiring manual review

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %%
Model-vs-baseline table
Prediction/error chart
Feature-importance chart
Ranked opportunity table
Any chart/table that appears on the deployed research-paper page.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
